# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
OUT_FILE='/Users/youjia/Downloads/test1.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')

user_timeline = api.user_timeline(count=20,page=18,screen_name='XHNews',tweet_mode='extended')
Japanesetext=[]
for i, tw in enumerate(user_timeline):
    ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
print('done')
# Out:
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/Japanesetext1-10.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(100)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='CCTV',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/Japanesetext1-10.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='XHJapanese',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/RT19-7-18.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(100)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='RT_com',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/XINHUAEnglishtext19-7-13.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(30)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='XHNews',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/BBC19-7-18.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(100)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='BBCWorld',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/VOAEnglishtext19-7-13.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(20)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='VOANews',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/BBCUK19-7-18.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(100)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='BBCNews',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/CGTNEnglishtext19-7-18.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(500)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='CGTNOfficial',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done 20
# done 21
# done 22
# done 23
# done 24
# done 25
# done 26
# done 27
# done 28
# done 29
# done 30
# done 31
# done 32
# done 33
# done 34
# done 35
# done 36
# done 37
# done 38
# done 39
# done 40
# done 41
# done 42
# done 43
# done 44
# done 45
# done 46
# done 47
# done 48
# done 49
# done 50
# done 51
# done 52
# done 53
# done 54
# done 55
# done 56
# done 57
# done 58
# done 59
# done 60
# done 61
# done 62
# done 63
# done 64
# done 65
# done 66
# done 67
# done 68
# done 69
# done 70
# done 71
# done 72
# done 73
# done 74
# done 75
# done 76
# done 77
# done 78
# done 79
# done 80
# done 81
# done 82
# done 83
# done 84
# done 85
# done 86
# done 87
# done 88
# done 89
# done 90
# done 91
# done 92
# done 93
# done 94
# done 95
# done 96
# done 97
# done 98
# done 99
# ...

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/Chinesetext1-10.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='XinhuaChinese',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/VOAChinesetext19-7-13.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(20)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='VOAChinese',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done 11
# done 12
# done 13
# done 14
# done 15
# done 16
# done 17
# done 18
# done 19
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/PD-English.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='PDChina',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/PD-English.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='PDChina',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/PD-Chinese.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='PDChinese',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done

# %%
import tweepy
import csv
import TwitterAPIKey
CK = TwitterAPIKey.CONSUMER_KEY
CS = TwitterAPIKey.CONSUMER_SECRET
from datetime import timedelta
import csv
OUT_FILE='/Users/youjia/Downloads/PD-Japanese.txt'

auth = tweepy.OAuthHandler(CK,CS)
api = tweepy.API(auth)

k=range(11)
ow = csv.writer(open(OUT_FILE,'w',encoding='UTF-8'),delimiter='\t')
for m in k:
    user_timeline = api.user_timeline(count=200,page=m,screen_name='peopledailyJP',tweet_mode='extended',include_entities=True)
    for i, tw in enumerate(user_timeline):
        ow.writerow([i,str(tw.created_at+timedelta(hours=9)),tw.full_text.replace('\n',r'\n')])
    print('done',m)
print('done')
# Out:
# done 0
# done 1
# done 2
# done 3
# done 4
# done 5
# done 6
# done 7
# done 8
# done 9
# done 10
# done

# %%
import json
user_timeline = api.user_timeline(count=21,page=1,screen_name='XHJapanese',tweet_mode='extended', include_entities=True)
#print(user_timeline)
#for tw in user_timeline:
    #print(tw.entities.get('media'))
    #data1=json.loads(str(tw._json))
# Out:
# [Status(_api=<tweepy.api.API object at 0x10a1a5080>, _json={'created_at': 'Sat Jun 22 10:56:54 +0000 2019', 'id': 1142385971633119232, 'id_str': '1142385971633119232', 'full_text': '中国中部・湖北省鄖西県で14日、道路工事中に2,000年前の墓群が発見された。\n考古学者らによると、墓群は4つの墓からなり、鉄剣、鉄器、陶器などの遺物10点余りも発掘された。人間の骨や歯も見つかった。発掘された遺物の構造的特徴から、墓群は後漢時代（25～220年）のものであることがわかるという。 https://t.co/R5aZltjGHb', 'truncated': False, 'display_text_range': [0, 148], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1142385917321068544, 'id_str': '1142385917321068544', 'indices': [149, 172], 'media_url': 'http://pbs.twimg.com/media/D9qR8G5UwAApFcV.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9qR8G5UwAApFcV.jpg', 'url': 'https://t.co/R5aZltjGHb', 'display_url': 'pic.twitter.com/R5aZltjGHb', 'expanded_url': 'https://twitter.com/XHJapanese/status/1142385971633119232/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 900, 'h': 450, 'resize': 'fi
# ...
